# %%
import geopandas
import matplotlib.pyplot as plt
# Out:
# /Users/shriphani/miniconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
src = geopandas.read_file('/Users/shriphani/india_in_data/city_shapefiles/data/mumbai-street/edges/edges.shp')

# %%
src.head()
# Out:
#   key      osmid      highway oneway              length        from  \
# 0   0  215438684  residential  False              66.863  2248802330
# 1   0  215438630  residential  False  101.67399999999999  2248802342
# 2   0  289412579      primary   True              278.65  6136332304
# 3   0  289412579      primary   True               26.84  6136332322
# 4   0  654864028     tertiary   True  29.551000000000002  6136332324
#
#            to  name lanes bridge   ref access service tunnel maxspeed  \
# 0  2248802304  None  None   None  None   None    None   None     None
# 1  2248802313  None  None   None  None   None    None   None     None
# 2  4292746859  None  None   None  None   None    None   None     None
# 3  6136332304  None  None   None  None   None    None   None     None
# 4  6136332304  None  None   None  None   None    None   None     None
#
#   junction width                                           geometry
# ...

# %%
simplified = src.simplify(tolerance=100)

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots(facecolor='black',figsize=(25,25))
ax.axis('off')

src.plot(ax=ax, color='cyan')
